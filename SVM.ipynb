# %% [markdown]
# # SVM demo
# This is the demo of the Support Vector Machines
#
# Import necessary stuff

# %%
# %reset
# %matplotlib inline  
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %% [markdown]
# Load the dataset

# %%
iris = datasets.load_iris()
X = iris.data[:, :2]
y = iris.target

# %% [markdown]
# Look how does it looks like...
# ...it really wants to be refactored :(

# %%
plt.scatter([X[i, 0] for i in range(y.size) if (y[i] == 0.0)], [X[i, 1] for i in range(y.size) if (y[i] == 0.0)], c="red")
plt.scatter([X[i, 0] for i in range(y.size) if (y[i] == 1.0)], [X[i, 1] for i in range(y.size) if (y[i] == 1.0)], c="yellow")
plt.scatter([X[i, 0] for i in range(y.size) if (y[i] == 2.0)], [X[i, 1] for i in range(y.size) if (y[i] == 2.0)])

# %%
clf = svm.SVC(kernel='rbf', gamma=0.7, C=1.0).fit(X, y)

# %%
h = .02  # step size in the mesh
# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %%
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)

    # Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())

plt.show()
